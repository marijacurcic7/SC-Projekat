# %%
import numpy as np
import pandas as pd

import IPython.display as ipd

import librosa
import librosa.display

import matplotlib.pyplot as plt

import cv2
# %matplotlib inline

# %%
def display_sample(file_path):
    plt.figure(figsize=(12, 4))
    data, sample_rate = librosa.load(file_path)
    print("Sample rate: ", sample_rate)
    print("min-max range: ", np.min(data), 'to', np.max(data))
    _ = librosa.display.waveplot(data, sr=sample_rate)

# %%
sample1 = "dataset/Clarinet_Bb/ClBb-ord-C#4-ff-N-N1.wav"
sample2 = "dataset/Violoncello/Vc-ord-A5-pp-1c-N.wav"

# %%
ipd.Audio(sample1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_sample(sample1)
# Out:
# Sample rate:  22050
# min-max range:  -0.12512569 to 0.16081533

# %%
data, sample_rate = librosa.load(sample1)

# %%
data
# Out:
# array([-4.9257840e-05, -7.7633231e-05, -5.1626659e-05, ...,
#        -3.9307874e-05, -3.5451805e-05,  0.0000000e+00], dtype=float32)

# %%
a, index = librosa.effects.trim(data, top_db=60, frame_length=2048, hop_length=512)

# %%
a
# Out:
# array([-0.00200241, -0.00192179, -0.00170204, ...,  0.00337209,
#         0.00326642,  0.00304506], dtype=float32)

# %%
print(len(a))
b = librosa.display.waveplot(a, sr=sample_rate)
# Out:
# 46080

# %%
data, sample_rate = librosa.load(sample2)
a, index = librosa.effects.trim(data, top_db=60, frame_length=2048, hop_length=512)
print(a)
print(index)
b = librosa.display.waveplot(a, sr=sample_rate)
# Out:
# [-3.4763457e-06  5.5523542e-06 -1.7307533e-05 ...  5.9082970e-05
#   6.3295891e-05  5.9423917e-05]
# [     0 154112]

# %%
print(numpy.sin(2 * np.pi * 440.0 * np.arange(sample_rate * 1.0) / sample_rate))
print(len(a))
# Out:
# [ 0.          0.06264832  0.12505052 ... -0.18696144 -0.12505052
#  -0.06264832]
# 146432

# %%
y_out = a[:66150]
librosa.display.waveplot(y_out, sr=sample_rate)

# %%
display_sample(sample2)
# Out:
# Sample rate:  22050
# min-max range:  -0.11678867 to 0.08121244

# %%
display_sample(sample3)
# Out:
# Sample rate:  22050
# min-max range:  -0.115061 to 0.09895305

# %%
display_sample(sample4)
# Out:
# Sample rate:  22050
# min-max range:  -0.14376695 to 0.105866134

# %%
librosa_audio, librosa_sample_rate = librosa.load(sample1)

# %%
mfccs1 = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)
print(mfccs1.shape)
print(mfccs1)
# Out:
# (40, 297)
# [[-7.7678699e+02 -6.5922565e+02 -6.1240295e+02 ... -8.3795361e+02
#   -8.3741724e+02 -8.3970013e+02]
#  [ 7.7763824e+01  1.2323148e+02  1.5194833e+02 ...  3.1229012e+01
#    3.1665018e+01  2.9780029e+01]
#  [ 4.3665134e+01  4.8891472e+01  4.3210991e+01 ...  2.3143700e+01
#    2.2991585e+01  2.3785295e+01]
#  ...
#  [-4.7049546e+00 -2.5275600e+00 -1.5593623e+00 ...  1.0850999e+00
#    1.2625084e+00  2.2042195e-01]
#  [-2.7112322e+00 -3.6560324e-01  9.6550030e-01 ... -9.8910749e-02
#    5.1025951e-01 -1.5696561e-01]
#  [ 4.6851664e+00  4.8030248e+00 -1.4373479e+00 ... -5.3653109e-01
#   -1.0246892e+00 -1.4656622e+00]]

# %%
librosa_audio, librosa_sample_rate = librosa.load(sample2)
mfccs2 = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)

# %%
librosa_audio, librosa_sample_rate = librosa.load(sample3)
mfccs3 = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)

# %%
librosa_audio, librosa_sample_rate = librosa.load(sample4)
mfccs4 = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)

# %%
librosa.display.specshow(mfccs1, sr=librosa_sample_rate, x_axis="time")

# %%
librosa.display.specshow(mfccs2, sr=librosa_sample_rate, x_axis="time")

# %%
def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, sr=20050)
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccscaled = np.mean(mfccs.T, axis=0)
    
    except Exception as e:
        print(e)
        print("Error encountered while parsing file: ", file_name)
        return None
    
    return mfccscaled

# %%
def extract_spectogram(file_name):
    try:
        audio, sample_rate = librosa.load(file_name,res_type="kaiser_fast" ,sr=22050)
        a, index = librosa.effects.trim(audio, top_db=30, frame_length=2048, hop_length=512)
        y_out = a[:44100]
        spectrogram = librosa.feature.melspectrogram(y=y_out, sr=sample_rate, n_fft=2048, hop_length=1024)
        #print(spectrogram)
        spec_shape = spectrogram.shape
        if(spec_shape[1] < 44):
            print(spec_shape)
            print(file_name)
        spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
        #imarray = np.reshape(spectrogram, (128, -1, 3))
        #img_gray = np.dot(spectrogram[...,:3], [0.299, 0.587, 0.114])
        #img_resized = cv2.resize(img_gray, (128,128), interpolation=cv2.INTER_CUBIC)
        #print(img_resized.shape)
        #redgram = block_reduce(img_gray, block_size = (3,3), func = np.mean)
        #return img_gray
        #mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        #mfccscaled = np.mean(mfccs.T, axis=0)
        return
    
    except Exception as e:
        print(e)
        print("Error encountered while parsing file: ", file_name)
        return None
    
    return mfccscaled

# %%
folder_path = "dataset/"
folder_list = ["Accordion","Clarinet_Bb","Contrabass","Horn","Viola","Violin","Violoncello"]
features = []
onlyfiles = []

from os import listdir
from os.path import isfile, join

for folder_inst in folder_list:
    onlyfiles = onlyfiles + [f for f in listdir("dataset/" + folder_inst) if isfile(join("dataset/" + folder_inst + "/", f))]
    


for file in onlyfiles: 
    dodatak = ''
    if (file.split("-")[0] == "Acc"):
        dodatak = "Accordion"
    elif (file.split("-")[0] == "ClBb"):
        dodatak = "Clarinet_Bb"
    elif (file.split("-")[0] == "Cb"):
        dodatak = "Contrabass"
    elif (file.split("-")[0] == "Hn"):
        dodatak = "Horn"
    elif (file.split("-")[0] == "Va"):
        dodatak = "Viola"
    elif (file.split("-")[0] == "Vn"):
        dodatak = "Violin"
    elif (file.split("-")[0] == "Vc"):
        dodatak = "Violoncello"
    
    file_name = folder_path + dodatak + "/" + file
    a = file.split("-")
    instrument = a[0]
    pitch = a[2]
    if(len(pitch) == 3):
        pitch = pitch[:2]
    else:
        pitch = pitch[:1]
    data = extract_spectogram(file_name)
    #features.append([file_name, data, instrument, pitch])
    #print(img)

# %%
librosa.display.specshow(mfccs4, sr=librosa_sample_rate, x_axis="time")

# %%
features_df = pd.DataFrame(features, columns=["file", "feature", "instrument", "pitch"])

# %%
features_df.head()
# Out:
#                                           file  \
# 0  dataset/Accordion/Acc-ord-A#3-ff-alt1-N.wav
# 1  dataset/Accordion/Acc-ord-A#3-ff-alt2-N.wav
# 2     dataset/Accordion/Acc-ord-A#3-ff-N-N.wav
# 3  dataset/Accordion/Acc-ord-A#3-mf-alt1-N.wav
# 4  dataset/Accordion/Acc-ord-A#3-mf-alt2-N.wav
#
#                                              feature instrument pitch
# 0  [-522.72656, 33.109436, -28.978998, 23.477665,...        Acc    A#
# 1  [-484.57516, 23.046968, -27.752514, 22.844591,...        Acc    A#
# 2  [-524.283, -5.4364886, -15.23014, 18.644983, -...        Acc    A#
# 3  [-629.1855, 45.63802, -25.412355, 39.921444, -...        Acc    A#
# 4  [-656.28033, 28.434679, -9.782004, 35.14882, -...        Acc    A#

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
X = np.array(features_df.feature.tolist())
y = np.array(features_df.pitch.tolist())
yinst = np.array(features_df.instrument.tolist())

le = LabelEncoder()
leinst = LabelEncoder()
yy = le.fit_transform(y)
yyinst = leinst.fit_transform(yinst)

# %%
le.classes_
# Out:
# array(['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#'],
#       dtype='<U2')

# %%
len(le.classes_)
# Out:
# 7

# %%
from sklearn.svm import SVC
from sklearn import metrics

x_train, x_test, y_train, y_test = train_test_split(X, yyinst, test_size=0.2, shuffle=True, random_state=42)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, shuffle=True, random_state=42)

# %%
len(x_test)
# Out:
# 138

# %%
len(y_test)
# Out:
# 138

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, Conv3D
from keras.optimizers import Adam
from keras.utils import to_categorical

num_classes = len(le.classes_)
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# %%
model = SVC(kernel="linear")
model.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred_train = model.predict(x_train)
print("Train Accuracy:", metrics.accuracy_score(y_train, y_pred_train))

y_pred_test = model.predict(x_test)
print("Test Accuracy:", metrics.accuracy_score(y_test, y_pred_test))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.8405797101449275

# %%
len(y_pred_test)
# Out:
# 138

# %%
set(y_test) - set(y_pred_test)
# Out:
# set()

# %%
metrics.f1_score(y_test, y_pred_test, average='weighted', labels=np.unique(y_pred_test))
# Out:
# 0.8423518636004956

# %%
print(metrics.classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87        16
#            1       0.69      0.92      0.79        12
#            2       0.92      0.85      0.88        13
#            3       0.91      0.77      0.83        13
#            4       0.75      1.00      0.86         9
#            5       0.82      0.75      0.78        12
#            6       0.90      0.75      0.82        12
#            7       0.67      1.00      0.80         6
#            8       0.70      0.78      0.74         9
#            9       0.80      1.00      0.89         8
#           10       1.00      0.76      0.87        17
#           11       1.00      0.91      0.95        11
#
#     accuracy                           0.84       138
#    macro avg       0.84      0.86      0.84       138
# weighted avg       0.86      0.84      0.84       138

# %%
print(metrics.classification_report(y_test, y_pred_test, target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.93      0.81      0.87        16
#           A#       0.69      0.92      0.79        12
#            B       0.92      0.85      0.88        13
#            C       0.91      0.77      0.83        13
#           C#       0.75      1.00      0.86         9
#            D       0.82      0.75      0.78        12
#           D#       0.90      0.75      0.82        12
#            E       0.67      1.00      0.80         6
#            F       0.70      0.78      0.74         9
#           F#       0.80      1.00      0.89         8
#            G       1.00      0.76      0.87        17
#           G#       1.00      0.91      0.95        11
#
#     accuracy                           0.84       138
#    macro avg       0.84      0.86      0.84       138
# weighted avg       0.86      0.84      0.84       138

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, Conv3D, BatchNormalization, MaxPool2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import to_categorical

from keras.callbacks import ModelCheckpoint
from datetime import datetime

# %%
num_classes = len(le.classes_)
x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, shuffle=True, random_state=42)
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)
print(x_train.size)

#Define Model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(40,14088 )))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
#Compile
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
print(model.summary())
#Train and Test The Model
#model.fit(x_train, y_train, batch_size=32, epochs=60, verbose=1, validation_data=(x_test, y_test))
# model = Sequential([
#     Conv2D(filters=32, kernel_size=(11,11), strides=(1,1), activation='relu', input_shape=(227,227,3)),
#     BatchNormalization(),
#     Dropout(0.25),
#     MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     Conv2D(filters=64, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
#     BatchNormalization(),
#     Dropout(0.25),
#     MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
#     BatchNormalization(),
#     Dropout(0.25),
#     Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
#     BatchNormalization(),
#     Dropout(0.25),
#     MaxPool2D(pool_size=(3,3), strides=(2,2)),
#     Flatten(),
#     Dense(4096, activation='relu'),
#     Dropout(0.25),
#     Dense(10, activation='softmax')
# ])

# model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
# model.summary()


# num_epochs = 60
# batch_size = 32

# checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", verbose=1, save_best_only=True)

# start = datetime.now()
# model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_test, y_test), 
#           callbacks=[checkpointer], verbose=1)

# duration = datetime.now() - start
# print("Training completed in: ", duration)
# Out:
# 14088
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-e90127395eac> in <module>
#       7 #Define Model
#       8 model = Sequential()
# ----> 9 model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(40, )))
#      10 model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
#      11 model.add(MaxPooling2D(pool_size=(2, 2)))
#
# c:\users\jovana\desktop\virtual\soko\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     164                     # and create the node connecting the current layer
#     165                     # to the input layer we just created.
# --> 166                     layer(x)
#     167                     set_inputs = True
#     168             else:
#
# c:\users\jovana\desktop\virtual\soko\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# c:\users\jovana\desktop\virtual\soko\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     444                 # Raise exceptions in case the input is not compatible
#     445                 # with the input_spec specified in the layer constructor.
# --> 446                 self.assert_input_compatibility(inputs)
#     447
#     448                 # Collect input shapes to build layer.
#
# c:\users\jovana\desktop\virtual\soko\lib\site-packages\keras\engine\base_layer.py in assert_input_compatibility(self, inputs)
#     340                                      self.name + ': expected ndim=' +
#     341                                      str(spec.ndim) + ', found ndim=' +
# --> 342                                      str(K.ndim(x)))
#     343             if spec.max_ndim is not None:
#     344                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer conv2d_31: expected ndim=4, found ndim=2

# %%
# model = Sequential()

# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))
# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))

# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))
# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))
# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))
# model.add(Conv2D(8, (5, 5), activation='relu', input_shape=(8, 105, 600)))
# model.add(Dense(48, activation="relu", input_shape=(48,600)))
# model.add(Average(input_shape=(48)))
# model.add(Dense((48, 24), activation='softmax', input_shape=(24)))

# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
input_shape = x_train.shape

# %%
len(x_train[0])
# Out:
# 40

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1609   try:
# -> 1610     c_op = c_api.TF_FinishOperation(op_desc)
#    1611   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 3 from 1 for 'conv2d_20/convolution' (op: 'Conv2D') with input shapes: [?,551,1,40], [3,3,40,32].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-63cbd7c031fb> in <module>
#       1 model = Sequential()
# ----> 2 model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(551, 1, 40)))
#       3 model.add(MaxPooling2D(pool_size=(2, 2)))
#       4 model.add(Dropout(0.25))
#       5 model.add(Conv2D(64, (3, 3), activation='relu'))
#
# c:\python36\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     164                     # and create the node connecting the current layer
#     165                     # to the input layer we just created.
# --> 166                     layer(x)
#     167                     set_inputs = True
#     168             else:
#
# c:\python36\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# c:\python36\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     487             # Actually call the layer,
#     488             # collecting output(s), mask(s), and shape(s).
# --> 489             output = self.call(inputs, **kwargs)
#     490             output_mask = self.compute_mask(inputs, previous_mask)
#     491
#
# c:\python36\lib\site-packages\keras\layers\convolutional.py in call(self, inputs)
#     169                 padding=self.padding,
#     170                 data_format=self.data_format,
# --> 171                 dilation_rate=self.dilation_rate)
#     172         if self.rank == 3:
#     173             outputs = K.conv3d(
#
# c:\python36\lib\site-packages\keras\backend\tensorflow_backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    3715         padding=padding,
#    3716         data_format=tf_data_format,
# -> 3717         **kwargs)
#    3718     if data_format == 'channels_first' and tf_data_format == 'NHWC':
#    3719         x = tf.transpose(x, (0, 3, 1, 2))  # NHWC -> NCHW
#
# c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#     915       data_format=data_format,
#     916       dilations=dilations,
# --> 917       name=name)
#     918
#     919
#
# c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution)
#    1007           data_format=data_format,
#    1008           dilations=dilations,
# -> 1009           name=name)
#    1010     else:
#    1011       if channel_index == 1:
#
# c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1068                   padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1069                   explicit_paddings=explicit_paddings,
# -> 1070                   data_format=data_format, dilations=dilations, name=name)
#    1071   _result = _op.outputs[:]
#    1072   _inputs_flat = _op.inputs
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     791         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     792                          input_types=input_types, attrs=attr_protos,
# --> 793                          op_def=op_def)
#     794       return output_structure, op_def.is_stateful, op
#     795
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\func_graph.py in create_op(***failed resolving arguments***)
#     546     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     547         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 548         compute_device)
#     549
#     550   def capture(self, tensor, name=None):
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3427           input_types=input_types,
#    3428           original_op=self._default_original_op,
# -> 3429           op_def=op_def)
#    3430       self._create_op_helper(ret, compute_device=compute_device)
#    3431     return ret
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1771           op_def, inputs, node_def.attr)
#    1772       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1773                                 control_input_ops)
#    1774     # pylint: enable=protected-access
#    1775
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1611   except errors.InvalidArgumentError as e:
#    1612     # Convert to ValueError for backwards compatibility.
# -> 1613     raise ValueError(str(e))
#    1614
#    1615   return c_op
#
# ValueError: Negative dimension size caused by subtracting 3 from 1 for 'conv2d_20/convolution' (op: 'Conv2D') with input shapes: [?,551,1,40], [3,3,40,32].

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               10496
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 12)                3084
# _________________________________________________________________
# activation_6 (Activation)    (None, 12)                0
# =================================================================
# Total params: 79,372
# Trainable params: 79,372
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from datetime import datetime

num_epochs = 100
batch_size = 32

checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", verbose=1, save_best_only=True)

start = datetime.now()
model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_test, y_test), 
          callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in: ", duration)
# Out:
# Train on 551 samples, validate on 138 samples
# Epoch 1/100
# 551/551 [==============================] - 0s 335us/step - loss: 84.9144 - accuracy: 0.0907 - val_loss: 16.6256 - val_accuracy: 0.0797
#
# Epoch 00001: val_loss improved from inf to 16.62558, saving model to best_weights.hdf5
# Epoch 2/100
# 551/551 [==============================] - 0s 78us/step - loss: 52.5818 - accuracy: 0.0672 - val_loss: 10.4405 - val_accuracy: 0.0652
#
# Epoch 00002: val_loss improved from 16.62558 to 10.44046, saving model to best_weights.hdf5
# Epoch 3/100
# 551/551 [==============================] - 0s 77us/step - loss: 32.0029 - accuracy: 0.0962 - val_loss: 3.5611 - val_accuracy: 0.1159
#
# Epoch 00003: val_loss improved from 10.44046 to 3.56111, saving model to best_weights.hdf5
# Epoch 4/100
# 551/551 [==============================] - 0s 78us/step - loss: 20.8705 - accuracy: 0.1162 - val_loss: 2.3776 - val_accuracy: 0.1377
#
# Epoch 00004: val_loss improved from 3.56111 to 2.37758, saving model to best_weights.hdf5
# Epoch 5/100
# 551/551 [==============================] - 0s 79us/step - loss: 13.4022 - accuracy: 0.1252 - val_loss: 2.4733 - val_accuracy: 0.0942
#
# Epoch 00005: val_loss did not improve from 2.37758
# Epoch 6/100
# 551/551 [==============================] - 0s 81us/step - loss: 8.7344 - accuracy: 0.1416 - val_loss: 2.4850 - val_accuracy: 0.0580
#
# Epoch 00006: val_loss did not improve from 2.37758
# Epoch 7/100
# 551/551 [==============================] - 0s 79us/step - loss: 6.5849 - accuracy: 0.1198 - val_loss: 2.4860 - val_accuracy: 0.0580
#
# Epoch 00007: val_loss did not improve from 2.37758
# Epoch 8/100
# 551/551 [==============================] - 0s 80us/step - loss: 4.9020 - accuracy: 0.1289 - val_loss: 2.4865 - val_accuracy: 0.0580
#
# Epoch 00008: val_loss did not improve from 2.37758
# Epoch 9/100
# 551/551 [==============================] - 0s 78us/step - loss: 4.1475 - accuracy: 0.1143 - val_loss: 2.4868 - val_accuracy: 0.0435
#
# Epoch 00009: val_loss did not improve from 2.37758
# Epoch 10/100
# 551/551 [==============================] - 0s 79us/step - loss: 3.5901 - accuracy: 0.1198 - val_loss: 2.4872 - val_accuracy: 0.0435
#
# Epoch 00010: val_loss did not improve from 2.37758
# Epoch 11/100
# 551/551 [==============================] - 0s 80us/step - loss: 3.3367 - accuracy: 0.0998 - val_loss: 2.4874 - val_accuracy: 0.0435
#
# Epoch 00011: val_loss did not improve from 2.37758
# Epoch 12/100
# 551/551 [==============================] - 0s 77us/step - loss: 3.0965 - accuracy: 0.1143 - val_loss: 2.4880 - val_accuracy: 0.0435
#
# Epoch 00012: val_loss did not improve from 2.37758
# Epoch 13/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.9817 - accuracy: 0.0962 - val_loss: 2.4885 - val_accuracy: 0.0435
#
# Epoch 00013: val_loss did not improve from 2.37758
# Epoch 14/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.8536 - accuracy: 0.1343 - val_loss: 2.4891 - val_accuracy: 0.0435
#
# Epoch 00014: val_loss did not improve from 2.37758
# Epoch 15/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.7346 - accuracy: 0.1234 - val_loss: 2.4896 - val_accuracy: 0.0435
#
# Epoch 00015: val_loss did not improve from 2.37758
# Epoch 16/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.6782 - accuracy: 0.1143 - val_loss: 2.4904 - val_accuracy: 0.0435
#
# Epoch 00016: val_loss did not improve from 2.37758
# Epoch 17/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.6847 - accuracy: 0.1107 - val_loss: 2.4909 - val_accuracy: 0.0435
#
# Epoch 00017: val_loss did not improve from 2.37758
# Epoch 18/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.7509 - accuracy: 0.1016 - val_loss: 2.4914 - val_accuracy: 0.0435
#
# Epoch 00018: val_loss did not improve from 2.37758
# Epoch 19/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.5935 - accuracy: 0.1307 - val_loss: 2.4921 - val_accuracy: 0.0435
#
# Epoch 00019: val_loss did not improve from 2.37758
# Epoch 20/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.6189 - accuracy: 0.1234 - val_loss: 2.4929 - val_accuracy: 0.0435
#
# Epoch 00020: val_loss did not improve from 2.37758
# Epoch 21/100
# 551/551 [==============================] - 0s 82us/step - loss: 2.6024 - accuracy: 0.1143 - val_loss: 2.4936 - val_accuracy: 0.0435
#
# Epoch 00021: val_loss did not improve from 2.37758
# Epoch 22/100
# 551/551 [==============================] - 0s 85us/step - loss: 2.5974 - accuracy: 0.1125 - val_loss: 2.4943 - val_accuracy: 0.0435
#
# Epoch 00022: val_loss did not improve from 2.37758
# Epoch 23/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5768 - accuracy: 0.1125 - val_loss: 2.4950 - val_accuracy: 0.0435
#
# Epoch 00023: val_loss did not improve from 2.37758
# Epoch 24/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.6285 - accuracy: 0.1071 - val_loss: 2.4953 - val_accuracy: 0.0435
#
# Epoch 00024: val_loss did not improve from 2.37758
# Epoch 25/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.6206 - accuracy: 0.1107 - val_loss: 2.4960 - val_accuracy: 0.0435
#
# Epoch 00025: val_loss did not improve from 2.37758
# Epoch 26/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5649 - accuracy: 0.1089 - val_loss: 2.4966 - val_accuracy: 0.0435
#
# Epoch 00026: val_loss did not improve from 2.37758
# Epoch 27/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5050 - accuracy: 0.1143 - val_loss: 2.4972 - val_accuracy: 0.0435
#
# Epoch 00027: val_loss did not improve from 2.37758
# Epoch 28/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.4921 - accuracy: 0.1053 - val_loss: 2.4978 - val_accuracy: 0.0435
#
# Epoch 00028: val_loss did not improve from 2.37758
# Epoch 29/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5797 - accuracy: 0.1162 - val_loss: 2.4983 - val_accuracy: 0.0435
#
# Epoch 00029: val_loss did not improve from 2.37758
# Epoch 30/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4992 - accuracy: 0.1143 - val_loss: 2.4989 - val_accuracy: 0.0435
#
# Epoch 00030: val_loss did not improve from 2.37758
# Epoch 31/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.5063 - accuracy: 0.1198 - val_loss: 2.4994 - val_accuracy: 0.0435
#
# Epoch 00031: val_loss did not improve from 2.37758
# Epoch 32/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5168 - accuracy: 0.1089 - val_loss: 2.4999 - val_accuracy: 0.0435
#
# Epoch 00032: val_loss did not improve from 2.37758
# Epoch 33/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.5073 - accuracy: 0.1216 - val_loss: 2.5002 - val_accuracy: 0.0435
#
# Epoch 00033: val_loss did not improve from 2.37758
# Epoch 34/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.4924 - accuracy: 0.1270 - val_loss: 2.5008 - val_accuracy: 0.0435
#
# Epoch 00034: val_loss did not improve from 2.37758
# Epoch 35/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4971 - accuracy: 0.0998 - val_loss: 2.5011 - val_accuracy: 0.0435
#
# Epoch 00035: val_loss did not improve from 2.37758
# Epoch 36/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.5303 - accuracy: 0.1234 - val_loss: 2.5013 - val_accuracy: 0.0435
#
# Epoch 00036: val_loss did not improve from 2.37758
# Epoch 37/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.5200 - accuracy: 0.1053 - val_loss: 2.5019 - val_accuracy: 0.0435
#
# Epoch 00037: val_loss did not improve from 2.37758
# Epoch 38/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5203 - accuracy: 0.1216 - val_loss: 2.5024 - val_accuracy: 0.0435
#
# Epoch 00038: val_loss did not improve from 2.37758
# Epoch 39/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5210 - accuracy: 0.1180 - val_loss: 2.5028 - val_accuracy: 0.0435
#
# Epoch 00039: val_loss did not improve from 2.37758
# Epoch 40/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4933 - accuracy: 0.1143 - val_loss: 2.5033 - val_accuracy: 0.0435
#
# Epoch 00040: val_loss did not improve from 2.37758
# Epoch 41/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4968 - accuracy: 0.1125 - val_loss: 2.5036 - val_accuracy: 0.0435
# Epoch 00041: val_loss did not improve from 2.37758
# Epoch 42/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4907 - accuracy: 0.1107 - val_loss: 2.5041 - val_accuracy: 0.0435
#
# Epoch 00042: val_loss did not improve from 2.37758
# Epoch 43/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5348 - accuracy: 0.1089 - val_loss: 2.5047 - val_accuracy: 0.0435
#
# Epoch 00043: val_loss did not improve from 2.37758
# Epoch 44/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4897 - accuracy: 0.1125 - val_loss: 2.5048 - val_accuracy: 0.0435
#
# Epoch 00044: val_loss did not improve from 2.37758
# Epoch 45/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5087 - accuracy: 0.1071 - val_loss: 2.5051 - val_accuracy: 0.0435
#
# Epoch 00045: val_loss did not improve from 2.37758
# Epoch 46/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5066 - accuracy: 0.1180 - val_loss: 2.5054 - val_accuracy: 0.0435
#
# Epoch 00046: val_loss did not improve from 2.37758
# Epoch 47/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5125 - accuracy: 0.1180 - val_loss: 2.5056 - val_accuracy: 0.0435
#
# Epoch 00047: val_loss did not improve from 2.37758
# Epoch 48/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4807 - accuracy: 0.1143 - val_loss: 2.5063 - val_accuracy: 0.0435
#
# Epoch 00048: val_loss did not improve from 2.37758
# Epoch 49/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5166 - accuracy: 0.1125 - val_loss: 2.5067 - val_accuracy: 0.0435
#
# Epoch 00049: val_loss did not improve from 2.37758
# Epoch 50/100
# 551/551 [==============================] - 0s 73us/step - loss: 2.4712 - accuracy: 0.1143 - val_loss: 2.5071 - val_accuracy: 0.0435
#
# Epoch 00050: val_loss did not improve from 2.37758
# Epoch 51/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4985 - accuracy: 0.1180 - val_loss: 2.5075 - val_accuracy: 0.0435
#
# Epoch 00051: val_loss did not improve from 2.37758
# Epoch 52/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4844 - accuracy: 0.1089 - val_loss: 2.5077 - val_accuracy: 0.0435
#
# Epoch 00052: val_loss did not improve from 2.37758
# Epoch 53/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4841 - accuracy: 0.1107 - val_loss: 2.5078 - val_accuracy: 0.0435
#
# Epoch 00053: val_loss did not improve from 2.37758
# Epoch 54/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4890 - accuracy: 0.1162 - val_loss: 2.5080 - val_accuracy: 0.0435
#
# Epoch 00054: val_loss did not improve from 2.37758
# Epoch 55/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4962 - accuracy: 0.1162 - val_loss: 2.5079 - val_accuracy: 0.0435
#
# Epoch 00055: val_loss did not improve from 2.37758
# Epoch 56/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.5025 - accuracy: 0.1162 - val_loss: 2.5082 - val_accuracy: 0.0435
#
# Epoch 00056: val_loss did not improve from 2.37758
# Epoch 57/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4856 - accuracy: 0.1125 - val_loss: 2.5087 - val_accuracy: 0.0435
#
# Epoch 00057: val_loss did not improve from 2.37758
# Epoch 58/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.4761 - accuracy: 0.1162 - val_loss: 2.5094 - val_accuracy: 0.0435
#
# Epoch 00058: val_loss did not improve from 2.37758
# Epoch 59/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4822 - accuracy: 0.1180 - val_loss: 2.5098 - val_accuracy: 0.0435
#
# Epoch 00059: val_loss did not improve from 2.37758
# Epoch 60/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.4902 - accuracy: 0.1053 - val_loss: 2.5102 - val_accuracy: 0.0435
#
# Epoch 00060: val_loss did not improve from 2.37758
# Epoch 61/100
# 551/551 [==============================] - 0s 73us/step - loss: 2.5003 - accuracy: 0.1107 - val_loss: 2.5106 - val_accuracy: 0.0435
#
# Epoch 00061: val_loss did not improve from 2.37758
# Epoch 62/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.5115 - accuracy: 0.1216 - val_loss: 2.5109 - val_accuracy: 0.0435
#
# Epoch 00062: val_loss did not improve from 2.37758
# Epoch 63/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4755 - accuracy: 0.1180 - val_loss: 2.5111 - val_accuracy: 0.0435
#
# Epoch 00063: val_loss did not improve from 2.37758
# Epoch 64/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4914 - accuracy: 0.1198 - val_loss: 2.5113 - val_accuracy: 0.0435
#
# Epoch 00064: val_loss did not improve from 2.37758
# Epoch 65/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.5219 - accuracy: 0.1162 - val_loss: 2.5116 - val_accuracy: 0.0435
#
# Epoch 00065: val_loss did not improve from 2.37758
# Epoch 66/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4707 - accuracy: 0.1107 - val_loss: 2.5118 - val_accuracy: 0.0435
#
# Epoch 00066: val_loss did not improve from 2.37758
# Epoch 67/100
# 551/551 [==============================] - 0s 75us/step - loss: 2.4911 - accuracy: 0.1089 - val_loss: 2.5122 - val_accuracy: 0.0435
#
# Epoch 00067: val_loss did not improve from 2.37758
# Epoch 68/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4861 - accuracy: 0.1162 - val_loss: 2.5122 - val_accuracy: 0.0435
#
# Epoch 00068: val_loss did not improve from 2.37758
# Epoch 69/100
# 551/551 [==============================] - 0s 76us/step - loss: 2.4918 - accuracy: 0.1198 - val_loss: 2.5127 - val_accuracy: 0.0435
#
# Epoch 00069: val_loss did not improve from 2.37758
# Epoch 70/100
# 551/551 [==============================] - 0s 71us/step - loss: 2.4527 - accuracy: 0.1180 - val_loss: 2.5131 - val_accuracy: 0.0435
#
# Epoch 00070: val_loss did not improve from 2.37758
# Epoch 71/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4822 - accuracy: 0.1143 - val_loss: 2.5136 - val_accuracy: 0.0435
#
# Epoch 00071: val_loss did not improve from 2.37758
# Epoch 72/100
# 551/551 [==============================] - 0s 74us/step - loss: 2.4654 - accuracy: 0.1198 - val_loss: 2.5140 - val_accuracy: 0.0435
#
# Epoch 00072: val_loss did not improve from 2.37758
# Epoch 73/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4498 - accuracy: 0.1252 - val_loss: 2.5143 - val_accuracy: 0.0435
#
# Epoch 00073: val_loss did not improve from 2.37758
# Epoch 74/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.5051 - accuracy: 0.1234 - val_loss: 2.5027 - val_accuracy: 0.0580
#
# Epoch 00074: val_loss did not improve from 2.37758
# Epoch 75/100
# 551/551 [==============================] - 0s 83us/step - loss: 2.4567 - accuracy: 0.1289 - val_loss: 2.5146 - val_accuracy: 0.0435
#
# Epoch 00075: val_loss did not improve from 2.37758
# Epoch 76/100
# 551/551 [==============================] - 0s 83us/step - loss: 2.4573 - accuracy: 0.1107 - val_loss: 2.5150 - val_accuracy: 0.0435
#
# Epoch 00076: val_loss did not improve from 2.37758
# Epoch 77/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.4874 - accuracy: 0.1234 - val_loss: 2.5140 - val_accuracy: 0.0435
#
# Epoch 00077: val_loss did not improve from 2.37758
# Epoch 78/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.4427 - accuracy: 0.1343 - val_loss: 2.5062 - val_accuracy: 0.0507
#
# Epoch 00078: val_loss did not improve from 2.37758
# Epoch 79/100
# 551/551 [==============================] - 0s 82us/step - loss: 2.4454 - accuracy: 0.1216 - val_loss: 2.5065 - val_accuracy: 0.0507
#
# Epoch 00079: val_loss did not improve from 2.37758
# Epoch 80/100
# 551/551 [==============================] - 0s 82us/step - loss: 2.4160 - accuracy: 0.1325 - val_loss: 2.4483 - val_accuracy: 0.0942
#
# Epoch 00080: val_loss did not improve from 2.37758
# Epoch 81/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.4321 - accuracy: 0.1325 - val_loss: 2.4997 - val_accuracy: 0.0652
#
# Epoch 00081: val_loss did not improve from 2.37758
# Epoch 82/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.4723 - accuracy: 0.1270 - val_loss: 2.5151 - val_accuracy: 0.0435
#
# Epoch 00082: val_loss did not improve from 2.37758
# Epoch 83/100
# 551/551 [==============================] - 0s 85us/step - loss: 2.4467 - accuracy: 0.1270 - val_loss: 2.5084 - val_accuracy: 0.0507
#
# Epoch 00083: val_loss did not improve from 2.37758
# Epoch 84/100
# 551/551 [==============================] - 0s 83us/step - loss: 2.4193 - accuracy: 0.1397 - val_loss: 2.4861 - val_accuracy: 0.0652
#
# Epoch 00084: val_loss did not improve from 2.37758
# Epoch 85/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.4199 - accuracy: 0.1343 - val_loss: 2.4537 - val_accuracy: 0.0942
#
# Epoch 00085: val_loss did not improve from 2.37758
# Epoch 86/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.4516 - accuracy: 0.1397 - val_loss: 2.4341 - val_accuracy: 0.1014
#
# Epoch 00086: val_loss did not improve from 2.37758
# Epoch 87/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.4275 - accuracy: 0.1252 - val_loss: 2.4689 - val_accuracy: 0.0870
#
# Epoch 00087: val_loss did not improve from 2.37758
# Epoch 88/100
# 551/551 [==============================] - 0s 83us/step - loss: 2.4134 - accuracy: 0.1343 - val_loss: 2.4661 - val_accuracy: 0.0870
#
# Epoch 00088: val_loss did not improve from 2.37758
# Epoch 89/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.4104 - accuracy: 0.1434 - val_loss: 2.4336 - val_accuracy: 0.1014
#
# Epoch 00089: val_loss did not improve from 2.37758
# Epoch 90/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.3879 - accuracy: 0.1361 - val_loss: 2.4244 - val_accuracy: 0.1014
#
# Epoch 00090: val_loss did not improve from 2.37758
# Epoch 91/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.3878 - accuracy: 0.1506 - val_loss: 2.4345 - val_accuracy: 0.0942
#
# Epoch 00091: val_loss did not improve from 2.37758
# Epoch 92/100
# 551/551 [==============================] - 0s 79us/step - loss: 2.3504 - accuracy: 0.1615 - val_loss: 2.3542 - val_accuracy: 0.1159
#
# Epoch 00092: val_loss improved from 2.37758 to 2.35424, saving model to best_weights.hdf5
# Epoch 93/100
# 551/551 [==============================] - 0s 83us/step - loss: 2.4063 - accuracy: 0.1543 - val_loss: 2.4389 - val_accuracy: 0.0942
#
# Epoch 00093: val_loss did not improve from 2.35424
# Epoch 94/100
# 551/551 [==============================] - 0s 78us/step - loss: 2.3942 - accuracy: 0.1525 - val_loss: 2.4102 - val_accuracy: 0.1014
#
# Epoch 00094: val_loss did not improve from 2.35424
# Epoch 95/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.4150 - accuracy: 0.1506 - val_loss: 2.3432 - val_accuracy: 0.1232
#
# Epoch 00095: val_loss improved from 2.35424 to 2.34317, saving model to best_weights.hdf5
# Epoch 96/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.3716 - accuracy: 0.1561 - val_loss: 2.3721 - val_accuracy: 0.1159
#
# Epoch 00096: val_loss did not improve from 2.34317
# Epoch 97/100
# 551/551 [==============================] - 0s 77us/step - loss: 2.3261 - accuracy: 0.1670 - val_loss: 2.3668 - val_accuracy: 0.1159
#
# Epoch 00097: val_loss did not improve from 2.34317
# Epoch 98/100
# 551/551 [==============================] - 0s 80us/step - loss: 2.3736 - accuracy: 0.1506 - val_loss: 2.3575 - val_accuracy: 0.1159
#
# Epoch 00098: val_loss did not improve from 2.34317
# Epoch 99/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.3008 - accuracy: 0.1706 - val_loss: 2.2752 - val_accuracy: 0.1667
#
# Epoch 00099: val_loss improved from 2.34317 to 2.27521, saving model to best_weights.hdf5
# Epoch 100/100
# 551/551 [==============================] - 0s 81us/step - loss: 2.3135 - accuracy: 0.1779 - val_loss: 2.2027 - val_accuracy: 0.1812
#
# Epoch 00100: val_loss improved from 2.27521 to 2.20273, saving model to best_weights.hdf5
# Training completed in:  0:00:07.171408

# %%
train_score = model.evaluate(x_train, y_train, verbose=1)
print("Training Accuracy: ", train_score[1])
# Out:
# 551/551 [==============================] - 0s 29us/step
# Training Accuracy:  0.21234120428562164

# %%
test_score = model.evaluate(x_test, y_test, verbose=1)
print("Test Accuracy: ", test_score[1])
# Out:
# 138/138 [==============================] - 0s 43us/step
# Test Accuracy:  0.18115942180156708
